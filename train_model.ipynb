# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.6/877.6 kB 43.4 MB/s eta 0:00:00
# ...

# %%
# Import YOLOv8 from ultralytics
from ultralytics import YOLO

# Additional libraries for handling data and visualization
import os
import numpy as np
import pandas as pd
from PIL import Image
import cv2  # For image preprocessing and manipulation
import matplotlib.pyplot as plt  # For visualizing results
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
#loading model
model = YOLO("yolov8n.yaml")

#use the model
results = model.train(data="/content/drive/MyDrive/dataset/config.yaml", epochs=7)
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython import display
display.clear_output()
from IPython.display import Image
import os
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 34.1/112.6 GB disk)

# %%
Image(filename='/content/runs/detect/train/train_batch0.jpg', width=600)

# %%
Image(filename='/content/runs/detect/train/confusion_matrix.png', width=600)
